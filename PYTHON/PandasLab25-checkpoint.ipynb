# %% [markdown]
# Lab1: Write a Pandas program to split the following data frame into groups based
# on Class and count the number of students in that particular class.Also generate
# a bar chart based on the result and explain the conclusion.

# %%
import pandas as pd
import matplotlib.pyplot as plt

student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'VI', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill',
             'David Parkes'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
})
print("Original DataFrame:")
print(student_data)

grouped_data = student_data.groupby('class').size()
print("\nClass wise No of students count:")
print(grouped_data)

plt.bar(grouped_data.index, grouped_data.values)
plt.xlabel('Class')
plt.ylabel('Number of Students')
plt.title('Number of Students per Class')
plt.show()
# Out:
# Original DataFrame:
#   school_code class            name  age  height  weight  address
# 0        s001     V  Alberto Franco   12     173      35  street1
# 1        s002    VI    Gino Mcneill   12     192      32  street2
# 2        s003    VI     Ryan Parkes   13     186      33  street3
# 3        s001    VI    Eesha Hinton   13     167      30  street1
# 4        s002     V    Gino Mcneill   14     151      31  street2
# 5        s004    VI    David Parkes   12     159      32  street4
#
# Class wise No of students count:
# class
# V     2
# VI    4
# dtype: int64

# %% [markdown]
# Lab2: Write a Pandas program to split the following dataframe by school
# code and get mean, min, and max value of age for each school.
# Also generate a horizontal bar chart based on the result and explain the
# conclusion.

# %%
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'VI', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill',
             'David Parkes'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
})
print("Original DataFrame:")
print(student_data)

student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'VI', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill',
             'David Parkes'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']
})

grouped_data = student_data.groupby('school_code')['age'].agg(['mean', 'min', 'max'])

grouped_data.plot(kind='barh', title='Age Statistics by School Code')
plt.xlabel('Age Statistics')
plt.ylabel('School Code')
plt.show()
# Out:
# Original DataFrame:
#   school_code class            name  age  height  weight  address
# 0        s001     V  Alberto Franco   12     173      35  street1
# 1        s002    VI    Gino Mcneill   12     192      32  street2
# 2        s003    VI     Ryan Parkes   13     186      33  street3
# 3        s001    VI    Eesha Hinton   13     167      30  street1
# 4        s002     V    Gino Mcneill   14     151      31  street2
# 5        s004    VI    David Parkes   12     159      32  street4

# %% [markdown]
# Lab3: Write a Pandas program to split a dataset, group by one column and
# get mean, min, and max values by group. Using the following dataset find
# the mean, min, and max values of purchase amount (purch_amt) group by
# customer id (customer_id).Also generate a line chart based on the result and
# explain the conclusion.

# %%
df = pd.DataFrame({
    'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002, 5003, 5001, np.nan, 5002, 5001, 5001, np.nan, 5003, 5002, 5003, np.nan]
})
print("Original Dataframe:")
print(df)
grouped_data = df.groupby('ord_date')['purch_amt'].agg(['mean','min','max'])
print(grouped_data)
grouped_data.plot(kind='bar', title='Purchase Amount Statistics by Customer ID')
plt.xlabel('customer_id')
plt.ylabel('Purchase Amount')
plt.show()
# Out:
# Original Dataframe:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#                    mean      min      max
# ord_date
# 2012-04-25  3045.600000  3045.60  3045.60
# 2012-06-27   250.450000   250.45   250.45
# 2012-07-27  2400.600000  2400.60  2400.60
# 2012-08-17    92.895000    75.29   110.50
# 2012-09-10  2326.383333   270.65  5760.00
# 2012-10-05   150.500000   150.50   150.50
# 2012-10-10  2231.915000  1983.43  2480.40

# %% [markdown]
# Lab4: Write a Pandas program to split the following data frame into groups
# and calculate monthly purchase amount.Also generate a bar chart based on
# the result and explain the conclusion.

# %%
df = pd.DataFrame({
    'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002, 5003, 5001, np.nan, 5002, 5001, 5001, np.nan, 5003, 5002, 5003, np.nan]
})
print("Original Dataframe:")
print(df)

grouped_data = df.groupby('ord_date')['purch_amt'].sum()
print(grouped_data)

grouped_data.plot(kind='line', title='Purchase Amount Statistics by Customer ID')
plt.xlabel('ord_id')
plt.ylabel('Purchase Amount')
plt.show()
# Out:
# Original Dataframe:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
# ord_date
# 2012-04-25    3045.60
# 2012-06-27     250.45
# 2012-07-27    2400.60
# 2012-08-17     185.79
# 2012-09-10    6979.15
# 2012-10-05     150.50
# 2012-10-10    4463.83
# Name: purch_amt, dtype: float64
