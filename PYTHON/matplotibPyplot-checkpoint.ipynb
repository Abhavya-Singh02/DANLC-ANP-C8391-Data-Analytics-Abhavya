# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,4))
x = (1,2,3,4,5)
y = (5,6,1,2,9)
plt.plot(x,y, marker="o", ms=10)
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

x = ("Good", "Better", "Best", "Best", "Best", "Good", "Better", "Better", "Better", "Better")
count = Counter(x)

plt.figure(figsize=(3,3))  
plt.bar(count.keys(), count.values())
plt.xlabel('Categories')
plt.ylabel('Count')
plt.title('Category Counts')

plt.show()

# %% [markdown]
# Lab1: Visualize the daily temperature changes over time in a city and give your
# conclusion
# Input:
# days = list(range(1, 32))
# # Daily temperature data (replace with your own data)
# temperature = [65, 68, 70, 72, 75, 76, 78, 80, 81, 79, 75, 72, 70, 68, 67, 69, 70, 73, 75, 76, 78,
# 80, 81, 82, 83, 82, 80, 78, 76, 74, 71]

# %%
temperature = [65, 68, 70, 72, 75, 76, 78, 80, 81, 79, 75, 72, 70, 68, 67, 69, 70, 73, 75, 76, 78, 80, 81, 82, 83, 82, 80, 78, 76, 74, 71]
days = list(range(1, 32))
plt.figure(figsize=(4,4))
plt.plot(days, temperature, marker="o", ms=3)

# %% [markdown]
# Lab2: Create a line plot to visualize the daily closing prices of a stock over a year
# and give your conclusion.
# Input:
# days = list(range(1, 78))
# # Daily closing prices of a stock (replace with your own data)

# %%
stock_prices = [100, 105, 110, 115, 112, 120,
118, 125, 128, 130, 132, 135,
138, 140, 142, 144, 145, 148,
150, 155, 160, 158, 162, 165,
170, 172, 175, 178, 180, 182,
185, 188, 190, 192, 195, 198,
200, 198, 195, 193, 190, 188,
185, 182, 180, 178, 175, 172,
170, 168, 165, 162, 160, 158,
155, 152, 150, 148, 145, 143,
140, 138, 135, 132, 130, 128,
125, 123, 120, 118, 115, 112,
110, 108, 105, 103, 100]

days=list(range(1,len(stock_prices)+1))

plt.figure(figsize=(3,3))  
plt.plot(days,stock_prices)
plt.xlabel('Day of the Year')
plt.ylabel('Stock Price (USD)')
plt.title("Stock Prices over a year")
plt.show()

# %% [markdown]
# Lab3: Create a bar chart to represent monthly expenses in different spending
# categories and give your conclusion.
# Input:
# categories = ['Rent', 'Groceries', 'Utilities', 'Entertainment', 'Transportation']
# # Monthly expenses in dollars (replace with your own data)
# expenses = [1200, 400, 200, 150, 250]

# %%
categories = ['Rent', 'Groceries', 'Utilities', 'Entertainment', 'Transportation']
# Monthly expenses in dollars (replace with your own data)
expenses = [1200, 400, 200, 150, 250]
plt.figure(figsize=(8,3))  
plt.bar(categories, expenses)
plt.xlabel("Expense categories")
plt.ylabel("Monthly Expenses (USD)")
plt.title("Monthly Expenses Breakdown")
# Out:
# Text(0.5, 1.0, 'Monthly Expenses Breakdown')

# %% [markdown]
# Lab4: Create a histogram to represent the distribution of product prices in a retail
# store and give your conclusion.
# Input:
# product_prices = [24.99, 34.99, 49.99, 64.99, 39.99, 54.99, 79.99, 99.99, 29.99, 44.99,
# 59.99, 69.99, 84.99, 109.99, 119.99, 89.99, 74.99, 124.99, 69.99, 54.99]

# %%
product_prices = [24.99, 34.99, 49.99, 64.99, 39.99, 54.99, 79.99, 99.99, 29.99, 44.99,
59.99, 69.99, 84.99, 109.99, 119.99, 89.99, 74.99, 124.99, 69.99, 54.99]
plt.figure(figsize=(8,7))  
plt.hist(product_prices, edgecolor="black")
plt.xlabel("Product Prices (USD)")
plt.ylabel("Number of Products")
plt.title("Distribution of product prices in a Retail Store")
# Out:
# Text(0.5, 1.0, 'Distribution of product prices in a Retail Store')

# %% [markdown]
# Hi! Suppose I am a teacher, and I want to analyze the exam scores of my students
# to understand how they performed on a recent math test. I have collected the exam
# scores, and I want to create a histogram to visualize the distribution of scores. Can you
# please generate a complete code.
# [Note: You need to share the exam scores in list format. For eg.
# 22,45,60,75,80] sample data.

# %%
exam_scores = [22, 45, 60, 75, 80, 85, 90, 92, 50, 67, 55, 80, 78, 62, 85]

# %%
import matplotlib.pyplot as plt

# Exam scores data
exam_scores = [22, 45, 60, 75, 80, 85, 90, 92, 50, 67, 55, 80, 78, 62, 85]
bin=[22,45,60,75,80]

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(exam_scores, bins=bin, edgecolor='black', color='skyblue')

# Adding labels and title
plt.xlabel('Scores')
plt.ylabel('Number of Students')
plt.title('Distribution of Exam Scores')

# Display the plot
plt.show()
